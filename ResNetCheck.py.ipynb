# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
clf_name = 'resnet_cleps'

X = np.load('%s_X.npy'%clf_name)
Y = np.load('%s_Y.npy'%clf_name)
net1 = np.load('%s_net1.npy'%clf_name)
net2 = np.load('%s_net2.npy'%clf_name)
net3 = np.load('%s_net3.npy'%clf_name)
net4 = np.load('%s_net4.npy'%clf_name)
net5 = np.load('%s_net5.npy'%clf_name)
net6 = np.load('%s_net6.npy'%clf_name)
net7 = np.load('%s_net7.npy'%clf_name)
net8 = np.load('%s_net8.npy'%clf_name)
net9 = np.load('%s_net9.npy'%clf_name)
net10 = np.load('%s_net10.npy'%clf_name)
net = np.load('%s_net.npy'%clf_name)

# %%
print(Y.min(), Y.max())
# Out:
# (0.0, 1.0)

# %%
norm = lambda im : (im-im.min())/(im.max()-im.min()) 
i = 1
x = X[i]
y = Y[i][:,:,0]
n1 = net1[i]
n2 = net2[i]
n3 = net3[i]
n4 = net4[i]
n5 = net5[i]
n6 = net6[i]
n7 = net7[i]
n8 = net8[i]
n9 = net9[i]
n10 = net10[i]
n = net[i]
plt.figure()
plt.imshow(norm(x))
plt.show()
plt.figure()
plt.imshow(y)
plt.show()

# %%
print(n1.min(), n1.max())
print(n2.min(), n2.max())
print(n3.min(), n3.max())
print(n4.min(), n4.max())
print(n5.min(), n5.max())
print(n6.min(), n6.max())
print(n7.min(), n7.max())
print(n8.min(), n8.max())
print(n9.min(), n9.max())
print(n10.min(), n10.max())
print(n.min(), n.max())
# Out:
# (0.0, 0.24715993)
# (0.0, 0.26057607)
# (0.0, 0.36149409)
# (0.0, 0.30071318)
# (0.0, 0.40858227)
# (0.0, 0.2287745)
# (0.0, 0.094393924)
# (0.0, 0.086593837)
# (0.0, 0.89977884)
# (-0.98063171, 0.98281974)
# (0.024827391, 0.085195042)

# %%
for i in range(0,256,64):
    plt.figure()
    plt.imshow(n6[:,:,i])
    plt.show()

# %%
'''plt.figure()
plt.imshow(n5mean)
plt.colorbar()
plt.figure()
plt.imshow(n5max)
plt.colorbar()
plt.figure()
plt.imshow(n[:,:,0])
plt.colorbar()
plt.show()'''

# %%
plt.figure(figsize=(15,15))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(n5[:,:,i])
plt.show()
